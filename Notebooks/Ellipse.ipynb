# %% [markdown]
# # Ellipse

# %%
import sympy
from conics.conic_factory import *

# %% [markdown]
# ----
# &nbsp;
# ## 'Standard' Ellipse

# %%
# Circle 1: General form with fractional coefficients, equivalent to a circle centered at (3, -2) with radius sqrt(35)
ellipse1 = "x**2/4 - 2*x/3 + y**2/9 + y/2 - 35/36"

e1 = Conic.create(ellipse1)
e1.get_info()
# Out:
# Original : x**2/4 - 2*x/3 + y**2/9 + y/2 - 35/36
# Type: Ellipse
# Coefficients: {(2, 0): 9, (1, 0): -24, (0, 2): 4, (0, 1): 18, (0, 0): -35}
# General Form: 9x^2 - 24x + 4y^2 + 18y - 35 = 0
#
# Matrix of coefficients:
# Matrix([
# [  9, 0, -12],
# [  0, 4,   9],
# [-12, 9, -35]])
# Quadratic Matrix:
# Matrix([
# [9, 0],
# [0, 4]])
# Orientation: vertical
#
# Centre: (4/3, -9/4)
# Equation of line through centre & semi-major axis
# Eq(x, 4/3)

# %%
# Translation to standard form needs to occur before certain attributes can be computed
# DEF - 'Standard Form', centre = (0, 0), orientation = 'horizontal'

e1.semimajor_axis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/s9/z74lxq2n7d9ct45y9_ffymd00000gn/T/ipykernel_62831/3537993044.py in <module>
#       2 # DEF - 'Standard Form', centre = (0, 0), orientation = 'horizontal'
#       3
# ----> 4 e1.semimajor_axis
#
# ~/Documents/Study/Stage3/Programming/Github/conic/conics/conic_factory.py in semimajor_axis(self)
#     701     def semimajor_axis(self):
#     702         if not self.standard_form:
# --> 703             raise ValueError("Semi-major axis can only be computed for ellipses in standard form")
#     704         a = self.A
#     705         return sympy.sqrt(1 / a)
#
# ValueError: Semi-major axis can only be computed for ellipses in standard form

# %%
e1.plot_standard()
# Out:
# Ellipse not in standard form

# %% [markdown]
# #### Translation and rotation are required based on `get_info()` plot

# %%
e1.translate_origin(display=True)
# Out:
# $\displaystyle \textbf{T}^T \cdot \textbf{M} \cdot \textbf{T}$
# $\displaystyle \left[\begin{matrix}1 & 0 & 0\\0 & 1 & 0\\h & k & 1\end{matrix}\right] \cdot \left[\begin{matrix}A & \frac{B}{2} & \frac{D}{2}\\\frac{B}{2} & C & \frac{E}{2}\\\frac{D}{2} & \frac{E}{2} & F\end{matrix}\right] \cdot \left[\begin{matrix}1 & 0 & h\\0 & 1 & k\\0 & 0 & 1\end{matrix}\right]$

# %%
e1.rotate(display=True)
# Out:
# $\displaystyle \textbf{R}^T \cdot \textbf{M} \cdot \textbf{R}$
# $\displaystyle \left[\begin{matrix}\cos{\left(\theta \right)} & - \sin{\left(\theta \right)} & 0\\\sin{\left(\theta \right)} & \cos{\left(\theta \right)} & 0\\0 & 0 & 1\end{matrix}\right] \cdot \left[\begin{matrix}A & \frac{B}{2} & \frac{D}{2}\\\frac{B}{2} & C & \frac{E}{2}\\\frac{D}{2} & \frac{E}{2} & F\end{matrix}\right] \cdot \left[\begin{matrix}\cos{\left(\theta \right)} & \sin{\left(\theta \right)} & 0\\- \sin{\left(\theta \right)} & \cos{\left(\theta \right)} & 0\\0 & 0 & 1\end{matrix}\right]$

# %%
# What did we just do?
e1.print_history()
# Out:
# Original input:
# x**2/4 - 2*x/3 + y**2/9 + y/2 - 35/36
#
# ----------
# Equation: 9x^2 - 24x + 4y^2 + 18y - 35 = 0
#
# ----------
# Translation of centre, (4/3, -9/4) to the origin
#
# Coefficients :
# {(2, 0): 9, (1, 1): 0, (0, 2): 4, (1, 0): 0, (0, 1): 0, (0, 0): -285/4}
#
# Matrix :
# Matrix([[9, 0, 0], [0, 4, 0], [0, 0, -285/4]])
#
# Equation :
# 9x^2 + 4y^2 - 285/4 = 0
#
# Orientation :
# ('vertical', 0)
#
# Centre :
# (0, 0)
#
# Standard Form? :
# False
#
# ----------
# Equation: 9x^2 + 4y^2 - 285/4 = 0
#
# ----------
# Performed rotation by 90.0 degrees CCW
#
# Coefficients :
# {(2, 0): 16/285, (1, 1): 0, (0, 2): 12/95, (1, 0): 0, (0, 1): 0, (0, 0): -1}
#
# Matrix :
# Matrix([[16/285, 0, 0], [0, 12/95, 0], [0, 0, -1]])
#
# Equation :
# 16x^2/285 + 12y^2/95 - 1 = 0
#
# Orientation :
# ('horizontal', 0)
#
# Centre :
# (0, 0)
#
# Standard Form? :
# True

# %%
e1.plot_standard()
# Out:
# ------
# Eccentricity:
#
# Approximation:  0.745
# Exact:
# √5
# ──
# 3
# ------
# Foci:
#
# Approximation:  (-3.15, 0)
# Exact:
# ⎛-5⋅√57    ⎞
# ⎜───────, 0⎟
# ⎝   12     ⎠
# Approximation:  (3.15, 0)
# Exact:
# ⎛5⋅√57   ⎞
# ⎜─────, 0⎟
# ⎝  12    ⎠
# ------
# Directrices:
#
# Approximation: x = -5.66
# Exact:
#     -3⋅√57
# x = ───────
#        4
# Approximation: x = 5.66
# Exact:
#     3⋅√57
# x = ─────
#       4
# ------
# Vertices:
#
# Approximation:  (-4.22, 0)
# Exact:
# ⎛-√285    ⎞
# ⎜──────, 0⎟
# ⎝  4      ⎠
# Approximation:  (4.22, 0)
# Exact:
# ⎛√285   ⎞
# ⎜────, 0⎟
# ⎝ 4     ⎠
# Approximation:  (0, -2.81)
# Exact:
# ⎛   -√285 ⎞
# ⎜0, ──────⎟
# ⎝     6   ⎠
# Approximation:  (0, 2.81)
# Exact:
# ⎛   √285⎞
# ⎜0, ────⎟
# ⎝    6  ⎠

# %% [markdown]
# ----
# &nbsp;
# ## Ellipse #2 - Rotated

# %%
rote2 = "3*x^2 - 8*x*y + 9*y^2 - 7*x - 3*y - 9"
re2 = Conic.create(rote2)
re2.get_info()
# Out:
# Original : 3*x^2 - 8*x*y + 9*y^2 - 7*x - 3*y - 9
# Type: Ellipse
# Coefficients: {(2, 0): 3, (1, 1): -8, (1, 0): -7, (0, 2): 9, (0, 1): -3, (0, 0): -9}
# General Form: 3x^2 - 8xy - 7x + 9y^2 - 3y - 9 = 0
#
# Matrix of coefficients:
# ⎡ 3     -4   -7/2⎤
# ⎢                ⎥
# ⎢ -4    9    -3/2⎥
# ⎢                ⎥
# ⎣-7/2  -3/2   -9 ⎦
# Quadratic Matrix:
# ⎡3   -4⎤
# ⎢      ⎥
# ⎣-4  9 ⎦
# Orientation: ('rotated', 26.565) degrees
# radians: atan(4/3)/2
#
# Centre: (75/22, 37/22)
# Equation of line through centre & semi-major axis
#                              ⎛atan(4/3)⎞
#                        75⋅tan⎜─────────⎟
#          ⎛atan(4/3)⎞         ⎝    2    ⎠   37
# y = x⋅tan⎜─────────⎟ - ───────────────── + ──
#          ⎝    2    ⎠           22          22

# %%
re2.translate_origin(display=True)
# Out:
# $\displaystyle \textbf{T}^T \cdot \textbf{M} \cdot \textbf{T}$
# $\displaystyle \left[\begin{matrix}1 & 0 & 0\\0 & 1 & 0\\h & k & 1\end{matrix}\right] \cdot \left[\begin{matrix}A & \frac{B}{2} & \frac{D}{2}\\\frac{B}{2} & C & \frac{E}{2}\\\frac{D}{2} & \frac{E}{2} & F\end{matrix}\right] \cdot \left[\begin{matrix}1 & 0 & h\\0 & 1 & k\\0 & 0 & 1\end{matrix}\right]$

# %%
re2.rotate(display=True)
# Out:
# $\displaystyle \textbf{R}^T \cdot \textbf{M} \cdot \textbf{R}$
# $\displaystyle \left[\begin{matrix}\cos{\left(\theta \right)} & - \sin{\left(\theta \right)} & 0\\\sin{\left(\theta \right)} & \cos{\left(\theta \right)} & 0\\0 & 0 & 1\end{matrix}\right] \cdot \left[\begin{matrix}A & \frac{B}{2} & \frac{D}{2}\\\frac{B}{2} & C & \frac{E}{2}\\\frac{D}{2} & \frac{E}{2} & F\end{matrix}\right] \cdot \left[\begin{matrix}\cos{\left(\theta \right)} & \sin{\left(\theta \right)} & 0\\- \sin{\left(\theta \right)} & \cos{\left(\theta \right)} & 0\\0 & 0 & 1\end{matrix}\right]$

# %%
re2.print_history()
# Out:
# Original input:
# 3*x^2 - 8*x*y + 9*y^2 - 7*x - 3*y - 9
#
# ----------
# Equation: 3x^2 - 8xy - 7x + 9y^2 - 3y - 9 = 0
#
# ----------
# Translation of centre, (75/22, 37/22) to the origin
#
# Coefficients :
# {(2, 0): 3, (1, 1): -8, (0, 2): 9, (1, 0): 0, (0, 1): 0, (0, 0): -258/11}
#
# Matrix :
# Matrix([[3, -4, 0], [-4, 9, 0], [0, 0, -258/11]])
#
# Equation :
# 3x^2 - 8xy + 9y^2 - 258/11 = 0
#
# Orientation :
# ('rotated', atan(4/3)/2)
#
# Centre :
# (0, 0)
#
# Standard Form? :
# False
#
# ----------
# Equation: 3x^2 - 8xy + 9y^2 - 258/11 = 0
#
# ----------
# Performed rotation by 153.4349 degrees CCW
#
# Coefficients :
# {(2, 0): 11/258, (1, 1): 0, (0, 2): 121/258, (1, 0): 0, (0, 1): 0, (0, 0): -1}
#
# Matrix :
# Matrix([[11/258, 0, 0], [0, 121/258, 0], [0, 0, -1]])
#
# Equation :
# 11x^2/258 + 121y^2/258 - 1 = 0
#
# Orientation :
# ('horizontal', 0)
#
# Centre :
# (0, 0)
#
# Standard Form? :
# True

# %%
re2.plot_standard(x_range=(-7.5, 7.5), y_range=(-5, 5))
# Out:
# ------
# Eccentricity:
#
# Approximation:  0.953
# Exact:
# √110
# ────
#  11
# ------
# Foci:
#
# Approximation:  (-4.62, 0)
# Exact:
# ⎛-2⋅√645    ⎞
# ⎜────────, 0⎟
# ⎝   11      ⎠
# Approximation:  (4.62, 0)
# Exact:
# ⎛2⋅√645   ⎞
# ⎜──────, 0⎟
# ⎝  11     ⎠
# ------
# Directrices:
#
# Approximation: x = -5.08
# Exact:
#     -√645
# x = ──────
#       5
# Approximation: x = 5.08
# Exact:
#     √645
# x = ────
#      5
# ------
# Vertices:
#
# Approximation:  (-4.84, 0)
# Exact:
# ⎛-√2838    ⎞
# ⎜───────, 0⎟
# ⎝   11     ⎠
# Approximation:  (4.84, 0)
# Exact:
# ⎛√2838   ⎞
# ⎜─────, 0⎟
# ⎝  11    ⎠
# Approximation:  (0, -1.46)
# Exact:
# ⎛   -√258 ⎞
# ⎜0, ──────⎟
# ⎝     11  ⎠
# Approximation:  (0, 1.46)
# Exact:
# ⎛   √258⎞
# ⎜0, ────⎟
# ⎝    11 ⎠

# %% [markdown]
# ----
# &nbsp;
# ## Ellipse #3 - Rotated

# %%
rote3 = "4*x^2+6*x*y+9*y^2-10*x+5*y-12"
re3 = Conic.create(rote3)
re3.get_info()
# Out:
# Original : 4*x^2+6*x*y+9*y^2-10*x+5*y-12
# Type: Ellipse
# Coefficients: {(2, 0): 4, (1, 1): 6, (1, 0): -10, (0, 2): 9, (0, 1): 5, (0, 0): -12}
# General Form: 4x^2 + 6xy - 10x + 9y^2 + 5y - 12 = 0
#
# Matrix of coefficients:
# ⎡4    3   -5 ⎤
# ⎢            ⎥
# ⎢3    9   5/2⎥
# ⎢            ⎥
# ⎣-5  5/2  -12⎦
# Quadratic Matrix:
# ⎡4  3⎤
# ⎢    ⎥
# ⎣3  9⎦
# Orientation: ('rotated', -25.097) degrees
# radians: -atan(6/5)/2
#
# Centre: (35/18, -25/27)
# Equation of line through centre & semi-major axis
#                                     ⎛atan(6/5)⎞
#                               35⋅tan⎜─────────⎟
#            ⎛atan(6/5)⎞   25         ⎝    2    ⎠
# y = - x⋅tan⎜─────────⎟ - ── + ─────────────────
#            ⎝    2    ⎠   27           18

# %%
re3.translate_origin(display=True)
# Out:
# $\displaystyle \textbf{T}^T \cdot \textbf{M} \cdot \textbf{T}$
# $\displaystyle \left[\begin{matrix}1 & 0 & 0\\0 & 1 & 0\\h & k & 1\end{matrix}\right] \cdot \left[\begin{matrix}A & \frac{B}{2} & \frac{D}{2}\\\frac{B}{2} & C & \frac{E}{2}\\\frac{D}{2} & \frac{E}{2} & F\end{matrix}\right] \cdot \left[\begin{matrix}1 & 0 & h\\0 & 1 & k\\0 & 0 & 1\end{matrix}\right]$

# %%
re3.rotate(display=True)
# Out:
# $\displaystyle \textbf{R}^T \cdot \textbf{M} \cdot \textbf{R}$
# $\displaystyle \left[\begin{matrix}\cos{\left(\theta \right)} & - \sin{\left(\theta \right)} & 0\\\sin{\left(\theta \right)} & \cos{\left(\theta \right)} & 0\\0 & 0 & 1\end{matrix}\right] \cdot \left[\begin{matrix}A & \frac{B}{2} & \frac{D}{2}\\\frac{B}{2} & C & \frac{E}{2}\\\frac{D}{2} & \frac{E}{2} & F\end{matrix}\right] \cdot \left[\begin{matrix}\cos{\left(\theta \right)} & \sin{\left(\theta \right)} & 0\\- \sin{\left(\theta \right)} & \cos{\left(\theta \right)} & 0\\0 & 0 & 1\end{matrix}\right]$

# %%
re3.print_history()
# Out:
# Original input:
# 4*x^2+6*x*y+9*y^2-10*x+5*y-12
#
# ----------
# Equation: 4x^2 + 6xy - 10x + 9y^2 + 5y - 12 = 0
#
# ----------
# Translation of centre, (35/18, -25/27) to the origin
#
# Coefficients :
# {(2, 0): 4, (1, 1): 6, (0, 2): 9, (1, 0): 0, (0, 1): 0, (0, 0): -649/27}
#
# Matrix :
# Matrix([[4, 3, 0], [3, 9, 0], [0, 0, -649/27]])
#
# Equation :
# 4x^2 + 6xy + 9y^2 - 649/27 = 0
#
# Orientation :
# ('rotated', -atan(6/5)/2)
#
# Centre :
# (0, 0)
#
# Standard Form? :
# False
#
# ----------
# Equation: 4x^2 + 6xy + 9y^2 - 649/27 = 0
#
# ----------
# Performed rotation by 25.0972 degrees CCW
#
# Coefficients :
# {(2, 0): 414/3835, (1, 1): 0, (0, 2): 945/2183, (1, 0): 0, (0, 1): 0, (0, 0): -1}
#
# Matrix :
# Matrix([[414/3835, 0, 0], [0, 945/2183, 0], [0, 0, -1]])
#
# Equation :
# 414x^2/3835 + 945y^2/2183 - 1 = 0
#
# Orientation :
# ('horizontal', 0)
#
# Centre :
# (0, 0)
#
# Standard Form? :
# True

# %%
re3.plot_standard(x_range=(-5, 5), y_range=(-5, 5))
# Out:
# ------
# Eccentricity:
#
# Approximation:  0.866
# Exact:
# √1398579
# ────────
#   1365
# ------
# Foci:
#
# Approximation:  (-2.64, 0)
# Exact:
# ⎛-√1459901310    ⎞
# ⎜─────────────, 0⎟
# ⎝    14490       ⎠
# Approximation:  (2.64, 0)
# Exact:
# ⎛√1459901310   ⎞
# ⎜───────────, 0⎟
# ⎝   14490      ⎠
# ------
# Directrices:
#
# Approximation: x = -3.51
# Exact:
#     -65⋅√1459901310
# x = ────────────────
#          706974
# Approximation: x = 3.51
# Exact:
#     65⋅√1459901310
# x = ──────────────
#         706974
# ------
# Vertices:
#
# Approximation:  (-3.04, 0)
# Exact:
# ⎛-√176410    ⎞
# ⎜─────────, 0⎟
# ⎝   138      ⎠
# Approximation:  (3.04, 0)
# Exact:
# ⎛√176410   ⎞
# ⎜───────, 0⎟
# ⎝  138     ⎠
# Approximation:  (0, -1.52)
# Exact:
# ⎛   -√229215 ⎞
# ⎜0, ─────────⎟
# ⎝      315   ⎠
# Approximation:  (0, 1.52)
# Exact:
# ⎛   √229215⎞
# ⎜0, ───────⎟
# ⎝     315  ⎠
