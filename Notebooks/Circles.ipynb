# %% [markdown]
# # Circles

# %%
import sympy
from conics.conic_factory import *

# %% [markdown]
# ----

# %% [markdown]
# ### 1.

# %%
circle1 = "(x + 2)**2 + (y + 3)**2 - 36"

c1 = Conic.create(circle1)
c1.get_info()
# Out:
# Original : (x + 2)**2 + (y + 3)**2 - 36
# Type: Circle
# Coefficients: {(2, 0): 1.0, (1, 0): 4.0, (0, 2): 1.0, (0, 1): 6.0, (0, 0): -23.0}
# General Form: x^2 + 4x + y^2 + 6y - 23 = 0
#
# Radius: 6.00
#
# Area: 36.0*pi
# approx 113.097 sq. units
#
# Circumference: 12.0*pi
# approx 37.6991 units
#
# Matrix of coefficients:
# [[  1.   0.   2.]
#  [  0.   1.   3.]
#  [  2.   3. -23.]]
#
# Quadratic Matrix:
# [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# ----
# ## 2.

# %%
circle2 = "(x - 4)**2 + (y - 5)**2 - 49"

c2 = Conic.create(circle2)
c2.get_info(x_range=(-5, 15), y_range=(-5, 15))
# Out:
# Original : (x - 4)**2 + (y - 5)**2 - 49
# Type: Circle
# Coefficients: {(2, 0): 1.0, (1, 0): -8.0, (0, 2): 1.0, (0, 1): -10.0, (0, 0): -8.0}
# General Form: x^2 - 8x + y^2 - 10y - 8 = 0
#
# Radius: 7.00
#
# Area: 49.0*pi
# approx 153.938 sq. units
#
# Circumference: 14.0*pi
# approx 43.9823 units
#
# Matrix of coefficients:
# [[ 1.  0. -4.]
#  [ 0.  1. -5.]
#  [-4. -5. -8.]]
#
# Quadratic Matrix:
# [[1. 0.]
#  [0. 1.]]

# %%
circle3 = "(x + 3)**2 + (y + 4)**2 - 64"

c3 = Conic.create(circle3)
c3.get_info(x_range=(-15, 7.5), y_range=(-15, 7.5))
# Out:
# Original : (x + 3)**2 + (y + 4)**2 - 64
# Type: Circle
# Coefficients: {(2, 0): 1.0, (1, 0): 6.0, (0, 2): 1.0, (0, 1): 8.0, (0, 0): -39.0}
# General Form: x^2 + 6x + y^2 + 8y - 39 = 0
#
# Radius: 8.00
#
# Area: 64.0*pi
# approx 201.062 sq. units
#
# Circumference: 16.0*pi
# approx 50.2655 units
#
# Matrix of coefficients:
# [[  1.   0.   3.]
#  [  0.   1.   4.]
#  [  3.   4. -39.]]
#
# Quadratic Matrix:
# [[1. 0.]
#  [0. 1.]]

# %%
circle4 = "(x - 2)**2 + (y - 3)**2 - 16"

c4 = Conic.create(circle4)
c4.get_info()
# Out:
# Original : (x - 2)**2 + (y - 3)**2 - 16
# Type: Circle
# Coefficients: {(2, 0): 1.0, (1, 0): -4.0, (0, 2): 1.0, (0, 1): -6.0, (0, 0): -3.0}
# General Form: x^2 - 4x + y^2 - 6y - 3 = 0
#
# Radius: 4.00
#
# Area: 16.0*pi
# approx 50.2655 sq. units
#
# Circumference: 8.0*pi
# approx 25.1327 units
#
# Matrix of coefficients:
# [[ 1.  0. -2.]
#  [ 0.  1. -3.]
#  [-2. -3. -3.]]
#
# Quadratic Matrix:
# [[1. 0.]
#  [0. 1.]]

# %%
circle5 = "(x + 1)**2 + (y + 1)**2 - 9"

c5 = Conic.create(circle5)
c5.get_info()
# Out:
# Original : (x + 1)**2 + (y + 1)**2 - 9
# Type: Circle
# Coefficients: {(2, 0): 1.0, (1, 0): 2.0, (0, 2): 1.0, (0, 1): 2.0, (0, 0): -7.0}
# General Form: x^2 + 2x + y^2 + 2y - 7 = 0
#
# Radius: 3.00
#
# Area: 9.0*pi
# approx 28.2743 sq. units
#
# Circumference: 6.0*pi
# approx 18.8496 units
#
# Matrix of coefficients:
# [[ 1.  0.  1.]
#  [ 0.  1.  1.]
#  [ 1.  1. -7.]]
#
# Quadratic Matrix:
# [[1. 0.]
#  [0. 1.]]

# %%
circle6 = "(x - 3)**2 + (y - 4)**2 - 25"

c6 = Conic.create(circle6)
c6.get_info()
# Out:
# Original : (x - 3)**2 + (y - 4)**2 - 25
# Type: Circle
# Coefficients: {(2, 0): 1.0, (1, 0): -6.0, (0, 2): 1.0, (0, 1): -8.0}
# General Form: x^2 - 6x + y^2 - 8y = 0
#
# Radius: 5.00
#
# Area: 25.0*pi
# approx 78.5398 sq. units
#
# Circumference: 10.0*pi
# approx 31.4159 units
#
# Matrix of coefficients:
# [[ 1.  0. -3.]
#  [ 0.  1. -4.]
#  [-3. -4.  0.]]
#
# Quadratic Matrix:
# [[1. 0.]
#  [0. 1.]]
