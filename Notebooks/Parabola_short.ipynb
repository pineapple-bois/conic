# %% [markdown]
# # Parabola Examples - Short

# %%
from conics.poly_dictionary import decompose_polynomial
from conics.conic_factory import *
from conics.plotting import plot_parabola, parabola_standard

# %% [markdown]
# ----
# &nbsp;
# ## Orientated to coordinate axes

# %%
# Parabola 1: General form equivalent to a parabola with vertex at (3, -2) and opens upwards
parabola1 = "((x - 3)**2) / 4 - 2"

p1 = Conic.create(parabola1)
p1.get_info()
# Out:
# Original : ((x - 3)**2) / 4 - 2
# Type: Parabola
# Coefficients: {(2, 0): 1.0, (1, 0): -6.0, (0, 1): -4.0, (0, 0): 1.0}
# General Form: x^2 - 6x - 4y + 1 = 0
#
# Matrix of coefficients:
# [[ 1.  0. -3.]
#  [ 0.  0. -2.]
#  [-3. -2.  1.]]
#
# Quadratic Matrix:
# [[1. 0.]
#  [0. 0.]]
#
# Orientation: ('vertical', 'positive')
# Axis of symmetry: 3

# %%
print(f"{p1.focus}\n{p1.directrix}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/s9/z74lxq2n7d9ct45y9_ffymd00000gn/T/ipykernel_25543/3662302490.py in <module>
# ----> 1 print(f"{p1.focus}\n{p1.directrix}")
#
# ~/Documents/Study/Stage3/Programming/Github/conic/conic_factory_history.py in focus(self)
#     241     def focus(self):
#     242         if not self.standard_form:
# --> 243             raise ValueError("The parabola is not in standard form")
#     244         return self.a, 0
#     245
#
# ValueError: The parabola is not in standard form

# %% [markdown]
# Because we haven't transformed it yet! Let's get it to standard form.

# %%
# Rotate it
p1.rotate_parabola(rational=True)
p1.plot_parabola()

# %%
# Translate it
p1.translate_origin(rational=True)
p1.plot_standard()

# %% [markdown]
# What did we just do?

# %%
p1.print_history()
# Out:
# Original input:
# ((x - 3)**2) / 4 - 2
#
# ----------
# Equation: x^2 - 6x - 4y + 1 = 0
#
# ----------
# Performed rotation by 270.0 degrees CCW
#
# Coefficients :
# {(2, 0): 0, (1, 1): 0, (0, 2): 1, (1, 0): -4, (0, 1): 6, (0, 0): 1}
#
# Matrix :
# [[0 0 -2]
#  [0 1 3]
#  [-2 3 1]]
#
# Equation :
# -4x + y^2 + 6y + 1 = 0
#
# Orientation :
# ('horizontal', 'positive')
#
# Vertex :
# (-2, -3)
#
# ----------
# Affine transformation of vertex (-2, -3) to the origin
#
# Coefficients :
# {(2, 0): 0, (1, 1): 0, (0, 2): 1, (1, 0): -4, (0, 1): 0, (0, 0): 0}
#
# Matrix :
# [[0 0 -2]
#  [0 1 0]
#  [-2 0 0]]
#
# Equation :
# -4x + y^2 = 0
#
# Orientation :
# ('horizontal', 'positive')
#
# Vertex :
# (0, 0)

# %% [markdown]
# ----
# &nbsp;
# ## Rotated - Gives some spicy rational numbers...

# %%
r1 = "x^2/4 + x*y/3 + y^2/9 -2*x + 3*y -1"
rot1 = Conic.create(r1)
rot1.get_info()
# Out:
# Original : x^2/4 + x*y/3 + y^2/9 -2*x + 3*y -1
# Type: Parabola
# Coefficients: {(2, 0): 9.0, (1, 1): 12.0, (1, 0): -72.0, (0, 2): 4.0, (0, 1): 108.0, (0, 0): -36.0}
# General Form: 9x^2 + 12xy - 72x + 4y^2 + 108y - 36 = 0
#
# Matrix of coefficients:
# [[  9.   6. -36.]
#  [  6.   4.  54.]
#  [-36.  54. -36.]]
#
# Quadratic Matrix:
# [[9. 6.]
#  [6. 4.]]
#
# Orientation: ('rotated', 0.588002603547568)
# Axis of symmetry: 78.0*x + 52.0*y

# %% [markdown]
# Zoom in

# %%
rot1.plot_parabola(x_range=(-1, 1), y_range=(-1, 1))

# %% [markdown]
# Rotate

# %%
rot1.rotate_parabola(rational=True)
rot1.plot_parabola()

# %% [markdown]
# Translate

# %%
rot1.translate_origin(rational=True)
rot1.plot_standard(x_range=(-7, 7), y_range=(-7, 7))

# %% [markdown]
# What did we just do?

# %%
rot1.print_history()
# Out:
# Original input:
# x^2/4 + x*y/3 + y^2/9 -2*x + 3*y -1
#
# ----------
# Equation: 9x^2 + 12xy - 72x + 4y^2 + 108y - 36 = 0
#
# ----------
# Performed rotation by 56.31 degrees CCW
#
# Coefficients :
# {(2, 0): 0, (1, 1): 0, (0, 2): 13, (1, 0): -4566926075806361/35184372088832, (0, 1): 0, (0, 0): -36}
#
# Matrix :
# [[0 0 -4566926075806361/70368744177664]
#  [0 13 0]
#  [-4566926075806361/70368744177664 0 -36]]
#
# Equation :
# -4566926075806361x/35184372088832 + 13y^2 - 36 = 0
#
# Orientation :
# ('horizontal', 'positive')
#
# Vertex :
# (-1266637395197952/4566926075806361, 0)
#
# ----------
# Affine transformation of vertex (-1266637395197952/4566926075806361, 0) to the origin
#
# Coefficients :
# {(2, 0): 0, (1, 1): 0, (0, 2): 13, (1, 0): -4566926075806361/35184372088832, (0, 1): 0, (0, 0): 0}
#
# Matrix :
# [[0 0 -4566926075806361/70368744177664]
#  [0 13 0]
#  [-4566926075806361/70368744177664 0 0]]
#
# Equation :
# -4566926075806361x/35184372088832 + 13y^2 = 0
#
# Orientation :
# ...

# %% [markdown]
# ----
# &nbsp;
# ## Rotated - Coefficients give nicer rational numbers this time!

# %%
r2 = "16*x^2 + 24*x*y + 9*y^2 -130*x - 90*y"
rot2 = Conic.create(r2)
rot2.get_info()
# Out:
# Original : 16*x^2 + 24*x*y + 9*y^2 -130*x - 90*y
# Type: Parabola
# Coefficients: {(2, 0): 16.0, (1, 1): 24.0, (1, 0): -130.0, (0, 2): 9.0, (0, 1): -90.0}
# General Form: 16x^2 + 24xy - 130x + 9y^2 - 90y = 0
#
# Matrix of coefficients:
# [[ 16.  12. -65.]
#  [ 12.   9. -45.]
#  [-65. -45.   0.]]
#
# Quadratic Matrix:
# [[16. 12.]
#  [12.  9.]]
#
# Orientation: ('rotated', 0.643501108793284)
# Axis of symmetry: 200.0*x + 150.0*y - 790.0

# %% [markdown]
# Does this look like a parabola? No.

# %% [markdown]
# However, it's been instantiated as such. The determinant of the quadratic matrix is zero such that $B^2=4AC$.

# %% [markdown]
# Therefore, we rotate.

# %%
rot2.rotate_parabola(rational=True)
rot2.plot_parabola()

# %% [markdown]
# The $x$ and $y$ range can be tweaked to best display the characteristics

# %%
rot2.translate_origin(rational=True)
rot2.plot_standard(x_range=(-0.2, 0.2), y_range=(-0.2, 0.2))

# %% [markdown]
# What did we do to get it as above?

# %%
rot2.print_history()
# Out:
# Original input:
# 16*x^2 + 24*x*y + 9*y^2 -130*x - 90*y
#
# ----------
# Performed rotation by 53.13 degrees CCW
#
# Coefficients :
# {(2, 0): 0, (1, 1): 0, (0, 2): 25, (1, 0): -6, (0, 1): -158, (0, 0): 0}
#
# Matrix :
# [[0 0 -3]
#  [0 25 -79]
#  [-3 -79 0]]
#
# Equation :
# -6*x + 25*y**2 - 158*y
#
# Orientation :
# ('horizontal', 'positive')
#
# Vertex :
# (-6241/150, 79/25)
#
# ----------
# Affine transformation of vertex (-6241/150, 79/25) to the origin
#
# Coefficients :
# {(2, 0): 0, (1, 1): 0, (0, 2): 25, (1, 0): -6, (0, 1): 0, (0, 0): 0}
#
# Matrix :
# [[0 0 -3]
#  [0 25 0]
#  [-3 0 0]]
#
# Equation :
# -6*x + 25*y**2
#
# Orientation :
# ('horizontal', 'positive')
#
# Vertex :
# (0, 0)

# %% [markdown]
# ----
