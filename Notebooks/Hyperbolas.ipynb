# %% [markdown]
# # Hyperbolas

# %%
import sympy
from conics.conic_factory import *

# %% [markdown]
# ----
# &nbsp;
# ### Examples

# %%
# Hyperbola 1: opens horizontally (x term is positive)
hyperbola1 = "x**2/9 - y**2/4 - 2*x/3 + y/2 - 1"
h1 = Conic.create(hyperbola1)
h1.get_info()
# Out:
# Original : x**2/9 - y**2/4 - 2*x/3 + y/2 - 1
# Type: Hyperbola
# Coefficients: {(2, 0): 4, (1, 0): -24, (0, 2): -9, (0, 1): 18, (0, 0): -36}
# General Form: 4x^2 - 24x - 9y^2 + 18y - 36 = 0
#
# Matrix of coefficients:
# Matrix([
# [  4,  0, -12],
# [  0, -9,   9],
# [-12,  9, -36]])
# Quadratic Matrix:
# Matrix([
# [4,  0],
# [0, -9]])
# Centre: (3, 1)
# Orientation: Horizontal
#
# Equation of transverse axis
# Eq(y, 1)

# %% [markdown]
# ----
# &nbsp;
# Example 2

# %%
# Hyperbola 2: opens vertically (y term is positive)
hyperbola2 = "(y-1)**2/16 - (x+1)**2/9 - 1"
h2 = Conic.create(hyperbola2)
h2.get_info()
# Out:
# Original : (y-1)**2/16 - (x+1)**2/9 - 1
# Type: Hyperbola
# Coefficients: {(2, 0): -16, (1, 0): -32, (0, 2): 9, (0, 1): -18, (0, 0): -151}
# General Form: -16x^2 - 32x + 9y^2 - 18y - 151 = 0
#
# Matrix of coefficients:
# Matrix([
# [-16,  0,  -16],
# [  0,  9,   -9],
# [-16, -9, -151]])
# Quadratic Matrix:
# Matrix([
# [-16, 0],
# [  0, 9]])
# Centre: (-1, 1)
# Orientation: Vertical
#
# Equation of transverse axis
# Eq(x, -1)

# %% [markdown]
# ----
# &nbsp;
# Example 3

# %%
# Hyperbola 3: Rectangular (coefficients of x and y are the same)
hyperbola3 = "(x-2)**2/4 - (y-3)**2/4 - 1"
h3 = Conic.create(hyperbola3)
h3.get_info()
# Out:
# Original : (x-2)**2/4 - (y-3)**2/4 - 1
# Type: Rectangular Hyperbola
# Coefficients: {(2, 0): 1, (1, 0): -4, (0, 2): -1, (0, 1): 6, (0, 0): -9}
# General Form: x^2 - 4x - y^2 + 6y - 9 = 0
#
# Matrix of coefficients:
# Matrix([
# [ 1,  0, -2],
# [ 0, -1,  3],
# [-2,  3, -9]])
# Quadratic Matrix:
# Matrix([
# [1,  0],
# [0, -1]])
# Centre: (2, 3)
# Orientation: Horizontal
#
# Equation of transverse axis
# Eq(y, 3)

# %%
# Hyperbola 4: rotated by some angle theta
hyperbola4 = "3*(x-1)**2 + 6*(x-1)*(y+2) - (y+2)**2 - 5"
h4 = Conic.create(hyperbola4)
h4.get_info()
# Out:
# Original : 3*(x-1)**2 + 6*(x-1)*(y+2) - (y+2)**2 - 5
# Type: Hyperbola
# Coefficients: {(2, 0): 3, (1, 1): 6, (1, 0): 6, (0, 2): -1, (0, 1): -10, (0, 0): -18}
# General Form: 3x^2 + 6xy + 6x - y^2 - 10y - 18 = 0
#
# Matrix of coefficients:
# Matrix([
# [3,  3,   3],
# [3, -1,  -5],
# [3, -5, -18]])
# Quadratic Matrix:
# Matrix([
# [3,  3],
# [3, -1]])
# Centre: (1, -2)
# Orientation: Rotated
#
# Equation of transverse axis
# Eq(y, x*tan(atan(3/2)/2) - 2 - tan(atan(3/2)/2))

# %%
# Hyperbola 5: rotated by some angle theta
hyperbola5 = "5*(x+2)**2 - 4*(x+2)*(y-3) - 2*(y-1)**2 - 7"
h5 = Conic.create(hyperbola5)
h5.get_info()
# Out:
# Original : 5*(x+2)**2 - 4*(x+2)*(y-3) - 2*(y-1)**2 - 7
# Type: Hyperbola
# Coefficients: {(2, 0): 5, (1, 1): -4, (1, 0): 32, (0, 2): -2, (0, 1): -4, (0, 0): 35}
# General Form: 5x^2 - 4xy + 32x - 2y^2 - 4y + 35 = 0
#
# Matrix of coefficients:
# Matrix([
# [ 5, -2, 16],
# [-2, -2, -2],
# [16, -2, 35]])
# Quadratic Matrix:
# Matrix([
# [ 5, -2],
# [-2, -2]])
# Centre: (-18/7, 11/7)
# Orientation: Rotated
#
# Equation of transverse axis
# Eq(y, -x*tan(atan(4/7)/2) - 18*tan(atan(4/7)/2)/7 + 11/7)
